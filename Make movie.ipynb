# %%
import moviepy
from moviepy.editor import *
from glob import glob

# %%
img_paths = glob('/home/wroscoe/mydonkey/sessions/1115am/*')
img_paths.sort()

# %%
clip = ImageSequenceClip(img_paths, 25)

# %%
sub = clip.subclip(0, 10)

# %%
sub.ipython_display()
# Out:
# 100%|█████████▉| 250/251 [00:00<00:00, 814.25it/s]
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
clip.write_videofile('test.mp4')
# Out:
# [MoviePy] >>>> Building video test.mp4
# [MoviePy] Writing video test.mp4
# 100%|██████████| 1301/1301 [00:03<00:00, 367.04it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test.mp4

# %%
sub.write_gif('test.gif')
# Out:
# [MoviePy] Building file test.gif with imageio
# 100%|█████████▉| 250/251 [00:03<00:00, 62.57it/s]

# %%
def make_gif(img_paths):
    clip = ImageSequenceClip(img_paths, 25)
    clip.write_videofile('test.mp4')

# %%
def make_video(img_paths):
    clip = ImageSequenceClip(img_paths, 25)
    clip.write_videofile('test.mp4')
    pa

# %%
def get_path():
    #gettime_
